# %%
#############################################################################
## This python script executes all the codes that generate all the         ##
##  up-to-date results seen in the paper draft.                            ##
##  Specifically, it includes following tasks                              ##
##  1. Importing, cleaning SCE data and undertakes the density estimtation ##
##  2. Using the estimated moments as inputs, analyze cross-sectional      ##
#        patterns of these moments.                                        ##
#   3. Examine the correlation between moments and stock market returns.   ##
#   4. Incorporates all the results in the master notebook.                ##
#   5. Convert the notebook into a latex and then compile it as a          ##
#   publishable pdf.                                                       ##
#############################################################################
#   When executed, the code first prompt a line  asking for user's         ##
#      input on if density estimation is needed?                           ##
#       'yes':  takes about 25-minutes - 30 minutes                        ##
#       or 'no': takes the stored estimates as input.                      ##
#############################################################################

import os 
import sys

# Find pathname to this file:
my_file_path = os.path.dirname(os.path.abspath("do_all.py"))

# %%
## python codes to run 
DoDensityEst_py =  os.path.join(my_file_path,"DoDensityEst.py")
MicroRiskProfile_py = os.path.join(my_file_path,"MicroRiskProfile.py")
MacroRiskProfile_py = os.path.join(my_file_path,"MacroRiskProfile.py")
PerceivedIncomeRisk_py = os.path.join(my_file_path,"PerceivedIncomeRisk.py")

# %%
do_denst = str(input("Do you want to redo density estimation?"   
                     "\n if yes, it takes about 30mins; if no, existing estimates are used, taking only 2-3 mins."))
# Out:
# Do you want to redo density estimation?
#  if yes, it takes about 30mins; if no, existing estimates are used, taking only 2-3 mins.no

# %%
if do_denst =='yes':
    print("Started running the codes.")
    print('1. Do density estimation of SCE.')
    exec(open(DoDensityEst_py).read())
    print('2. Individual level analysis')
    exec(open(MicroRiskProfile_py).read())
    print('3. Macro analysis')
    exec(open(MacroRiskProfile_py).read())
    print('4. Compile master notebook')
    exec(open(PerceivedIncomeRisk_py).read())
    print('5. Compile the latex file.')

elif do_denst == 'no':
    print("Started running the codes.")
    print('2. Individual level analysis')
    exec(open(MicroRiskProfile_py).read())
    print('3. Macro analysis')
    exec(open(MacroRiskProfile_py).read())
    print('4. Compile master notebook')
    exec(open(PerceivedIncomeRisk_py).read())
    
else:
    print('Wrong input. Need to type yes or no.')
    
print('Complete.\n Now, ready to run bash script "to_tex.sh" to compile the most recent PerceivedIncomeRisk.pdf' )
# Out:
# Started running the codes.
# 2. Individual level analysis
#                                           Perceived Income Risks
# ==========================================================================================================
#                    incvar I incvar II incvar III incvar IIII rincvar I rincvar II rincvar III rincvar IIII
# ----------------------------------------------------------------------------------------------------------
# C(HHinc)[T.10.0]                      -4.32***                                    -13.64***
#                                       (0.54)                                      (1.08)
# C(HHinc)[T.11.0]                      -2.23***                                    -11.70***
#                                       (0.55)                                      (1.10)
# C(HHinc)[T.2.0]                       -1.25**                                     -3.52***
#                                       (0.59)                                      (1.18)
# C(HHinc)[T.3.0]                       -1.63***                                    -2.67**
#                                       (0.55)                                      (1.09)
# C(HHinc)[T.4.0]                       -2.27***                                    -4.56***
#                                       (0.55)                                      (1.09)
# C(HHinc)[T.5.0]                       -3.61***                                    -8.25***
#                                       (0.54)                                      (1.08)
# C(HHinc)[T.6.0]                       -3.70***                                    -8.55***
#                                       (0.54)                                      (1.08)
# C(HHinc)[T.7.0]                       -4.15***                                    -10.43***
#                                       (0.53)                                      (1.06)
# C(HHinc)[T.8.0]                       -4.24***                                    -11.33***
#                                       (0.53)                                      (1.05)
# C(HHinc)[T.9.0]                       -4.47***                                    -12.91***
#                                       (0.53)                                      (1.05)
# C(educ)[T.2.0]                                   -4.81**                                      -6.15
#                                                  (1.98)                                       (4.37)
# C(educ)[T.3.0]                                   -5.74***                                     -11.82***
#                                                  (1.95)                                       (4.31)
# C(educ)[T.4.0]                                   -6.15***                                     -11.11**
#                                                  (1.96)                                       (4.34)
# C(educ)[T.5.0]                                   -6.09***                                     -15.64***
#                                                  (1.93)                                       (4.29)
# C(educ)[T.6.0]                                   -6.71***                                     -17.44***
#                                                  (1.95)                                       (4.31)
# C(educ)[T.7.0]                                   -6.54***                                     -19.89***
#                                                  (2.12)                                       (4.59)
# C(educ)[T.8.0]                                   -4.55**                                      -15.77***
#                                                  (2.07)                                       (4.51)
# C(educ)[T.9.0]                                   -7.79**                                      -20.74***
#                                                  (3.32)                                       (6.74)
# C(gender)[T.male]                                -0.82***                                     4.48***
#                                                  (0.29)                                       (0.57)
# C(parttime)[T.yes] -0.19    -0.01     -0.81***               0.91***   1.28***    -1.53***
#                    (0.13)   (0.13)    (0.15)                 (0.25)    (0.27)     (0.29)
# C(selfemp)[T.yes]  7.36***  -0.00***  0.00***                6.16***   0.00***    -0.00***
#                    (0.15)   (0.00)    (0.00)                 (0.29)    (0.00)     (0.00)
# Intercept          4.66***  4.03***   7.58***    12.84***    12.54***  14.07***   23.09***    30.30***
#                    (0.06)   (0.11)    (0.52)     (1.92)      (0.11)    (0.23)     (1.04)      (4.26)
# Stkprob                     0.01**    0.01***                          -0.05***   -0.04***
#                             (0.00)    (0.00)                           (0.00)     (0.00)
# UEprobInd                   0.03***   0.03***                          0.06***    0.05***
#                             (0.00)    (0.00)                           (0.01)     (0.01)
# N                  46027    39868     34475      6872        43237     37397      32614       6165
# R2                 0.05     0.00      0.01       0.00        0.01      0.01       0.04        0.03
# ==========================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
# 3. Macro analysis
#                             Unobserved Components Results
# =====================================================================================
# Dep. Variable:                       meanMed   No. Observations:                   60
# Model:                       fixed intercept   Log Likelihood                 -72.426
#                    + stochastic seasonal(12)   AIC                            146.853
# Date:                       Fri, 29 Nov 2019   BIC                            148.724
# Time:                               19:55:19   HQIC                           147.560
# Sample:                           06-01-2013
#                                 - 05-01-2018
# Covariance Type:                         opg
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# sigma2.seasonal     1.1039      0.288      3.838      0.000       0.540       1.668
# ===================================================================================
# Ljung-Box (Q):                      408.60   Jarque-Bera (JB):                 2.40
# Prob(Q):                              0.00   Prob(JB):                         0.30
# Heteroskedasticity (H):               0.40   Skew:                             0.11
# Prob(H) (two-sided):                  0.08   Kurtosis:                         1.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/Myworld/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /Users/Myworld/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.317
# Date:                Fri, 29 Nov 2019   Prob (F-statistic):              0.251
# Time:                        19:56:33   Log-Likelihood:            -1.3027e+05
# No. Observations:               38133   AIC:                         2.605e+05
# Df Residuals:                   38131   BIC:                         2.606e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.8815      0.039     98.319      0.000       3.804       3.959
# x1             1.5504      1.351      1.148      0.251      -1.097       4.198
# ==============================================================================
# Omnibus:                    26738.691   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           342501.834
# Skew:                           3.361   Prob(JB):                         0.00
# Kurtosis:                      16.052   Cond. No.                         35.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.215
# Date:                Fri, 29 Nov 2019   Prob (F-statistic):              0.270
# Time:                        19:56:33   Log-Likelihood:                -76867.
# No. Observations:               38133   AIC:                         1.537e+05
# Df Residuals:                   38131   BIC:                         1.538e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1970      0.010    225.756      0.000       2.178       2.216
# x1             0.3670      0.333      1.102      0.270      -0.286       1.020
# ==============================================================================
# Omnibus:                    14007.797   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            44562.407
# Skew:                           1.933   Prob(JB):                         0.00
# Kurtosis:                       6.620   Cond. No.                         35.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9397
# Date:                Fri, 29 Nov 2019   Prob (F-statistic):              0.332
# Time:                        19:56:33   Log-Likelihood:            -1.5863e+05
# No. Observations:               38133   AIC:                         3.173e+05
# Df Residuals:                   38131   BIC:                         3.173e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.1874      0.083    122.666      0.000      10.025      10.350
# x1             2.7566      2.842      0.970      0.332      -2.813       8.327
# ==============================================================================
# Omnibus:                    24059.504   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           244373.379
# Skew:                           2.991   Prob(JB):                         0.00
# Kurtosis:                      13.864   Cond. No.                         35.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4263
# Date:                Fri, 29 Nov 2019   Prob (F-statistic):              0.514
# Time:                        19:56:33   Log-Likelihood:                -21084.
# No. Observations:               38133   AIC:                         4.217e+04
# Df Residuals:                   38131   BIC:                         4.219e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0981      0.002     43.550      0.000       0.094       0.103
# x1            -0.0503      0.077     -0.653      0.514      -0.201       0.101
# ==============================================================================
# Omnibus:                    20629.743   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           995940.741
# Skew:                           1.894   Prob(JB):                         0.00
# Kurtosis:                      27.748   Cond. No.                         35.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 4. Compile master notebook
# Correlation of perceived risks and stock return of x months ahead
# Complete.
#  Now, ready to run bash script "to_tex.sh" to compile the most recent PerceivedIncomeRisk.pdf
